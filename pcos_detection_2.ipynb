# %% [markdown]
# #PCOS DETECTION USING YOLOV5 MODEL

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/zippedfile.zip -d /content/PCOS/

# %%
import os
import random
import shutil
# Set paths
dataset_path = "/content/PCOS/train"
images_path = os.path.join(dataset_path, "images")
labels_path = os.path.join(dataset_path, "labels")

# Output directories
train_images = os.path.join(dataset_path, "train", "images")
train_labels = os.path.join(dataset_path, "train", "labels")
val_images = os.path.join(dataset_path, "val", "images")
val_labels = os.path.join(dataset_path, "val", "labels")
test_images = os.path.join(dataset_path, "test", "images")
test_labels = os.path.join(dataset_path, "test", "labels")

# Create directories
for path in [train_images, train_labels, val_images, val_labels, test_images, test_labels]:
    os.makedirs(path, exist_ok=True)

# List all image files
image_files = [f for f in os.listdir(images_path) if f.endswith(('.jpg', '.png', '.jpeg'))]

# Shuffle and split
random.seed(42)
random.shuffle(image_files)
total = len(image_files)
train_end = int(0.7 * total)
val_end = int(0.85 * total)
train_files = image_files[:train_end]
val_files = image_files[train_end:val_end]
test_files = image_files[val_end:]

# Helper to move files
def move_files(file_list, src_img_dir, src_lbl_dir, dest_img_dir, dest_lbl_dir):
    for file in file_list:
        img_path = os.path.join(src_img_dir, file)
        label_path = os.path.join(src_lbl_dir, file.replace('.jpg', '.txt').replace('.png', '.txt').replace('.jpeg', '.txt'))

        if os.path.exists(img_path):
            shutil.move(img_path, os.path.join(dest_img_dir, file))
        if os.path.exists(label_path):
            shutil.move(label_path, os.path.join(dest_lbl_dir, os.path.basename(label_path)))
# Move files accordingly
move_files(train_files, images_path, labels_path, train_images, train_labels)
move_files(val_files, images_path, labels_path, val_images, val_labels)
move_files(test_files, images_path, labels_path, test_images, test_labels)

print(f"✅ Dataset split done: {len(train_files)} train, {len(val_files)} val, {len(test_files)} test")
# Out:
# ✅ Dataset split done: 2468 train, 529 val, 529 test

# %%
import os

image_dir = "/content/PCOS/train/val/images"  # Update with your image folder
label_dir = "/content/PCOS/train/val/labels"

image_exts = (".jpg", ".png", ".jpeg")  # Add other formats if needed
label_ext = ".txt"  # YOLO format uses .txt files for annotations

# Get filenames (without extensions)
image_files = {os.path.splitext(f)[0] for f in os.listdir(image_dir) if f.endswith(image_exts)}
label_files = {os.path.splitext(f)[0] for f in os.listdir(label_dir) if f.endswith(label_ext)}

# Find mismatches
missing_labels = image_files - label_files
extra_labels = label_files - image_files

print(f"✅ Matching Files: {len(image_files & label_files)}")
print(f"⚠ Missing Label Files: {len(missing_labels)}")
print(f"⚠ Extra Label Files: {len(extra_labels)}")

if missing_labels:
    print("\n🛑 Images without labels:", missing_labels)
if extra_labels:
    print("\n🛑 Labels without images:", extra_labels)
# Out:
# ✅ Matching Files: 529
# ⚠ Missing Label Files: 0
# ⚠ Extra Label Files: 0

# %%
data_yaml = """
train: /content/PCOS/train/train
val: /content/PCOS/train/val
test: /content/PCOS/train/test

nc: 1  # Only one class (PCOS)
names: ['PCOS']
"""

# Save the file
with open("/content/PCOS/train/data.yaml", "w") as f:
    f.write(data_yaml)

print("data.yaml file created successfully!")
# Out:
# data.yaml file created successfully!

# %%
import shutil

folder_path = "/content/PCOS"
output_zip = "/content/PCOS.zip"

shutil.make_archive(output_zip.replace('.zip', ''), 'zip', folder_path)
print("Folder zipped successfully!")
from google.colab import files

files.download(output_zip)
# Out:
# Folder zipped successfully!

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17395, done.
# remote: Counting objects: 100% (75/75), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 17395 (delta 57), reused 20 (delta 20), pack-reused 17320 (from 3)
# Receiving objects: 100% (17395/17395), 16.26 MiB | 28.96 MiB/s, done.
# Resolving deltas: 100% (11926/11926), done.

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
# !pip install -r requirements.txt

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data /content/PCOS/train/data.yaml --weights yolov5s.pt --device 0
# Out:
# Streaming output truncated to the last 5000 lines.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02149    0.02455          0         97        640:  16% 25/155 [00:09<00:50,  2.58it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02145    0.02425          0         51        640:  17% 26/155 [00:10<00:48,  2.65it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02154      0.024          0         62        640:  17% 27/155 [00:10<00:47,  2.70it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02152    0.02397          0         86        640:  18% 28/155 [00:10<00:43,  2.91it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02155    0.02421          0        110        640:  19% 29/155 [00:11<00:49,  2.56it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02136    0.02404          0         79        640:  19% 30/155 [00:11<00:45,  2.75it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02135    0.02445          0        136        640:  20% 31/155 [00:11<00:44,  2.80it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02134    0.02427          0         59        640:  21% 32/155 [00:12<00:38,  3.19it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02136    0.02425          0         74        640:  21% 33/155 [00:12<00:43,  2.78it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02133    0.02411          0         67        640:  22% 34/155 [00:13<00:43,  2.80it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02128    0.02406          0         87        640:  23% 35/155 [00:13<00:38,  3.14it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02133    0.02439          0        108        640:  23% 36/155 [00:13<00:38,  3.09it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G     0.0213    0.02436          0         90        640:  24% 37/155 [00:13<00:41,  2.84it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02139    0.02455          0         96        640:  25% 38/155 [00:14<00:43,  2.70it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02141    0.02415          0         38        640:  25% 39/155 [00:14<00:38,  3.04it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02146    0.02406          0         74        640:  26% 40/155 [00:14<00:38,  3.00it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02142    0.02408          0         92        640:  26% 41/155 [00:15<00:38,  2.96it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02147    0.02408          0         81        640:  27% 42/155 [00:15<00:37,  3.05it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02145    0.02408          0         79        640:  28% 43/155 [00:16<00:39,  2.84it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02146    0.02402          0         71        640:  28% 44/155 [00:16<00:35,  3.14it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02152    0.02424          0        113        640:  29% 45/155 [00:16<00:41,  2.65it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02155    0.02428          0         86        640:  30% 46/155 [00:17<00:38,  2.83it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G     0.0215    0.02435          0         92        640:  30% 47/155 [00:17<00:40,  2.63it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02147    0.02428          0         71        640:  31% 48/155 [00:17<00:36,  2.97it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02144    0.02417          0         70        640:  32% 49/155 [00:18<00:43,  2.43it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02146    0.02422          0         88        640:  32% 50/155 [00:18<00:42,  2.47it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02147    0.02432          0        108        640:  33% 51/155 [00:19<00:45,  2.29it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02142    0.02435          0         95        640:  34% 52/155 [00:19<00:40,  2.57it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02136     0.0242          0         60        640:  34% 53/155 [00:20<00:47,  2.13it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02136    0.02413          0         76        640:  35% 54/155 [00:20<00:44,  2.29it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02138    0.02416          0         74        640:  35% 55/155 [00:21<00:49,  2.04it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02144    0.02428          0        102        640:  36% 56/155 [00:21<00:43,  2.27it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02146    0.02408          0         46        640:  37% 57/155 [00:22<00:52,  1.87it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G     0.0215    0.02419          0        102        640:  37% 58/155 [00:22<00:45,  2.12it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02158    0.02422          0         84        640:  38% 59/155 [00:23<00:52,  1.82it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02158    0.02407          0         61        640:  39% 60/155 [00:23<00:44,  2.13it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02158    0.02402          0         76        640:  39% 61/155 [00:24<00:47,  1.97it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02162    0.02403          0         81        640:  40% 62/155 [00:24<00:40,  2.30it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02161    0.02404          0         90        640:  41% 63/155 [00:24<00:39,  2.34it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G     0.0216    0.02411          0        100        640:  41% 64/155 [00:25<00:33,  2.68it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02164    0.02414          0         88        640:  42% 65/155 [00:25<00:33,  2.69it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02162    0.02418          0         88        640:  43% 66/155 [00:25<00:31,  2.84it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02159    0.02417          0         86        640:  43% 67/155 [00:26<00:31,  2.84it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02159    0.02411          0         73        640:  44% 68/155 [00:26<00:27,  3.15it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02158    0.02406          0         66        640:  45% 69/155 [00:26<00:31,  2.77it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02158    0.02412          0        102        640:  45% 70/155 [00:27<00:29,  2.91it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02161    0.02403          0         60        640:  46% 71/155 [00:27<00:31,  2.64it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02163    0.02412          0        108        640:  46% 72/155 [00:27<00:28,  2.94it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02162    0.02427          0        121        640:  47% 73/155 [00:28<00:27,  2.93it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02164    0.02429          0         90        640:  48% 74/155 [00:28<00:26,  3.03it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02165    0.02429          0         91        640:  48% 75/155 [00:28<00:28,  2.77it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02165    0.02424          0         77        640:  49% 76/155 [00:29<00:26,  3.00it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02166    0.02424          0         79        640:  50% 77/155 [00:29<00:27,  2.80it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02164    0.02428          0        107        640:  50% 78/155 [00:29<00:26,  2.93it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02165     0.0244          0        123        640:  51% 79/155 [00:30<00:27,  2.79it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02163    0.02447          0        111        640:  52% 80/155 [00:30<00:26,  2.86it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02162    0.02445          0         70        640:  52% 81/155 [00:30<00:24,  2.97it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G     0.0216    0.02442          0         81        640:  53% 82/155 [00:31<00:23,  3.05it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02162     0.0244          0         77        640:  54% 83/155 [00:31<00:24,  2.93it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02162    0.02439          0         89        640:  54% 84/155 [00:31<00:22,  3.23it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02161    0.02448          0        107        640:  55% 85/155 [00:32<00:25,  2.79it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02159    0.02439          0         52        640:  55% 86/155 [00:32<00:23,  2.94it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02159    0.02448          0        105        640:  56% 87/155 [00:33<00:23,  2.85it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02158    0.02453          0         96        640:  57% 88/155 [00:33<00:21,  3.14it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02159    0.02464          0        105        640:  57% 89/155 [00:33<00:24,  2.69it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02158    0.02462          0         80        640:  58% 90/155 [00:34<00:24,  2.68it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G     0.0216    0.02475          0        119        640:  59% 91/155 [00:34<00:26,  2.40it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02157    0.02477          0         93        640:  59% 92/155 [00:34<00:23,  2.64it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02155    0.02465          0         53        640:  60% 93/155 [00:35<00:31,  1.98it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02154    0.02466          0         89        640:  61% 94/155 [00:36<00:27,  2.19it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02152    0.02463          0         79        640:  61% 95/155 [00:36<00:29,  2.00it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02152    0.02471          0        113        640:  62% 96/155 [00:37<00:26,  2.23it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02155    0.02468          0         67        640:  63% 97/155 [00:37<00:28,  2.02it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02154    0.02458          0         60        640:  63% 98/155 [00:37<00:24,  2.31it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02157     0.0246          0         87        640:  64% 99/155 [00:38<00:30,  1.84it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02155    0.02459          0         81        640:  65% 100/155 [00:39<00:25,  2.12it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02154    0.02458          0         74        640:  65% 101/155 [00:39<00:28,  1.89it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02151    0.02454          0         65        640:  66% 102/155 [00:39<00:24,  2.14it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G     0.0215    0.02449          0         56        640:  66% 103/155 [00:40<00:24,  2.13it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02147    0.02447          0         84        640:  67% 104/155 [00:40<00:20,  2.48it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02145    0.02453          0        110        640:  68% 105/155 [00:41<00:20,  2.48it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02142    0.02445          0         57        640:  68% 106/155 [00:41<00:18,  2.70it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02142    0.02444          0         80        640:  69% 107/155 [00:41<00:18,  2.63it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02142    0.02447          0        104        640:  70% 108/155 [00:42<00:15,  2.97it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G     0.0214    0.02451          0        100        640:  70% 109/155 [00:42<00:16,  2.85it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02139    0.02452          0         86        640:  71% 110/155 [00:42<00:15,  2.94it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02138    0.02452          0         90        640:  72% 111/155 [00:43<00:16,  2.65it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02137    0.02452          0         90        640:  72% 112/155 [00:43<00:14,  2.99it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02138    0.02453          0         91        640:  73% 113/155 [00:43<00:16,  2.57it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02138     0.0245          0         71        640:  74% 114/155 [00:44<00:14,  2.87it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02139    0.02451          0         96        640:  74% 115/155 [00:44<00:13,  2.91it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02138    0.02455          0        106        640:  75% 116/155 [00:44<00:12,  3.19it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G     0.0214    0.02456          0         85        640:  75% 117/155 [00:45<00:14,  2.68it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02138    0.02455          0         87        640:  76% 118/155 [00:45<00:12,  2.94it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02141    0.02461          0        108        640:  77% 119/155 [00:45<00:12,  2.82it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G     0.0214    0.02461          0         82        640:  77% 120/155 [00:46<00:11,  3.12it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G     0.0214    0.02463          0         92        640:  78% 121/155 [00:46<00:10,  3.18it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02138    0.02458          0         65        640:  79% 122/155 [00:46<00:11,  2.86it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02139    0.02457          0         80        640:  79% 123/155 [00:47<00:11,  2.91it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02145    0.02456          0         70        640:  80% 124/155 [00:47<00:10,  2.86it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02146     0.0246          0        103        640:  81% 125/155 [00:47<00:10,  2.85it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02148    0.02463          0         88        640:  81% 126/155 [00:48<00:10,  2.88it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02148    0.02459          0         61        640:  82% 127/155 [00:48<00:09,  2.98it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02148    0.02461          0        100        640:  83% 128/155 [00:48<00:08,  3.12it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02149    0.02456          0         60        640:  83% 129/155 [00:49<00:08,  3.02it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02151    0.02457          0         88        640:  84% 130/155 [00:49<00:08,  2.78it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G     0.0215    0.02455          0         76        640:  85% 131/155 [00:49<00:07,  3.16it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02152    0.02465          0        128        640:  85% 132/155 [00:50<00:07,  2.94it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02151    0.02467          0        100        640:  86% 133/155 [00:50<00:08,  2.50it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G     0.0215    0.02466          0         82        640:  86% 134/155 [00:51<00:08,  2.42it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G     0.0215    0.02464          0         67        640:  87% 135/155 [00:51<00:09,  2.16it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02151    0.02458          0         57        640:  88% 136/155 [00:52<00:08,  2.18it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02152     0.0247          0        136        640:  88% 137/155 [00:52<00:08,  2.23it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02152    0.02473          0        106        640:  89% 138/155 [00:53<00:08,  1.92it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02149    0.02466          0         53        640:  90% 139/155 [00:53<00:08,  1.89it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02149     0.0247          0        103        640:  90% 140/155 [00:54<00:07,  1.92it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02149     0.0247          0         88        640:  91% 141/155 [00:55<00:07,  1.88it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02148    0.02466          0         63        640:  92% 142/155 [00:55<00:06,  1.96it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G     0.0215    0.02459          0         47        640:  92% 143/155 [00:55<00:05,  2.11it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02148    0.02453          0         63        640:  93% 144/155 [00:56<00:04,  2.21it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02148    0.02455          0         94        640:  94% 145/155 [00:56<00:03,  2.58it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02148    0.02458          0        115        640:  94% 146/155 [00:57<00:03,  2.29it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02148    0.02468          0        123        640:  95% 147/155 [00:57<00:02,  2.68it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02149    0.02471          0         93        640:  95% 148/155 [00:57<00:02,  2.72it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02148    0.02473          0        101        640:  96% 149/155 [00:57<00:01,  3.00it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02148    0.02475          0        105        640:  97% 150/155 [00:58<00:01,  2.61it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02149    0.02477          0         83        640:  97% 151/155 [00:58<00:01,  2.96it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G     0.0215    0.02478          0         89        640:  98% 152/155 [00:58<00:01,  2.95it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02151    0.02479          0         91        640:  99% 153/155 [00:59<00:00,  3.28it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G    0.02151    0.02482          0         93        640:  99% 154/155 [00:59<00:00,  2.78it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      4.75G     0.0215    0.02497          0         43        640: 100% 155/155 [00:59<00:00,  2.59it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 17/17 [00:06<00:00,  2.54it/s]
#                    all        529       1911      0.724      0.821      0.799      0.553
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/155 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       35/49      4.75G    0.01873    0.02219          0         85        640:   1% 1/155 [00:00<00:40,  3.81it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       35/49      4.75G    0.02022    0.02492          0         84        640:   1% 2/155 [00:00<00:41,  3.66it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       35/49      4.75G    0.01933    0.02406          0         79        640:   2% 3/155 [00:00<00:47,  3.18it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       35/49      4.75G    0.01999    0.02397          0         74        640:   3% 4/155 [00:01<00:47,  3.20it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       35/49      4.75G    0.02019    0.02331          0         69        640:   3% 5/155 [00:01<00:43,  3.42it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       35/49      4.75G    0.01981    0.02298          0         73        640:   4% 6/155 [00:01<00:48,  3.08it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       35/49      4.75G     0.0202     0.0233          0         73        640:   5% 7/155 [00:02<01:11,  2.08it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       35/49      4.75G    0.02038    0.02392          0        102        640:   5% 8/155 [00:02<01:01,  2.40it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       35/49      4.75G    0.02056    0.02494          0        107        640:   6% 9/155 [00:03<01:07,  2.16it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       35/49      4.75G    0.02051    0.02579          0        112        640:   6% 10/155 [00:03<01:02,  2.30it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       35/49      4.75G    0.02083    0.02576          0         90        640:   7% 11/155 [00:04<01:07,  2.13it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       35/49      4.75G    0.02079     0.0254          0         74        640:   8% 12/155 [00:04<00:59,  2.41it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       35/49      4.75G    0.02102    0.02582          0        103        640:   8% 13/155 [00:05<00:57,  2.46it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       35/49      4.75G    0.02088     0.0259          0         99        640:   9% 14/155 [00:05<00:50,  2.80it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       35/49      4.75G    0.02085    0.02533          0         68        640:  10% 15/155 [00:05<00:57,  2.45it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       35/49      4.75G    0.02075    0.02571          0        104        640:  10% 16/155 [00:06<00:48,  2.88it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       35/49      4.75G    0.02072    0.02538          0         65        640:  11% 17/155 [00:06<00:54,  2.53it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       35/49      4.75G    0.02076    0.02489          0         50        640:  12% 18/155 [00:06<00:47,  2.86it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       35/49      4.75G    0.02088    0.02459          0         58        640:  12% 19/155 [00:07<00:54,  2.49it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       35/49      4.75G    0.02094    0.02472          0        102        640:  13% 20/155 [00:07<00:47,  2.86it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       35/49      4.75G    0.02099    0.02468          0         75        640:  14% 21/155 [00:07<00:44,  2.99it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       35/49      4.75G    0.02102     0.0245          0         82        640:  14% 22/155 [00:08<00:41,  3.23it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       35/49      4.75G    0.02101    0.02407          0         61        640:  15% 23/155 [00:08<00:52,  2.49it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       35/49      4.75G     0.0211    0.02426          0        100        640:  15% 24/155 [00:08<00:44,  2.92it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       35/49      4.75G    0.02114    0.02449          0         99        640:  16% 25/155 [00:09<00:44,  2.95it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# ...
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G    0.01996     0.0238          0        114        640:  68% 106/155 [00:41<00:17,  2.88it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G    0.01997    0.02383          0        112        640:  69% 107/155 [00:41<00:17,  2.67it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G    0.01996    0.02381          0         85        640:  70% 108/155 [00:41<00:15,  3.05it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G    0.01996    0.02376          0         67        640:  70% 109/155 [00:42<00:17,  2.67it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G    0.01997    0.02378          0         85        640:  71% 110/155 [00:42<00:14,  3.09it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G    0.01997    0.02378          0         83        640:  72% 111/155 [00:43<00:16,  2.70it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G    0.01997    0.02377          0         95        640:  72% 112/155 [00:43<00:15,  2.82it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G    0.01996    0.02379          0         95        640:  73% 113/155 [00:43<00:16,  2.61it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G    0.01995    0.02371          0         60        640:  74% 114/155 [00:44<00:13,  2.94it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G    0.01995    0.02366          0         53        640:  74% 115/155 [00:44<00:13,  2.95it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G    0.01996    0.02375          0        119        640:  75% 116/155 [00:44<00:12,  3.19it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G       0.02    0.02376          0         76        640:  75% 117/155 [00:45<00:13,  2.77it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G       0.02    0.02381          0        110        640:  76% 118/155 [00:45<00:11,  3.13it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G    0.02002    0.02374          0         54        640:  77% 119/155 [00:45<00:12,  2.94it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G    0.02003     0.0237          0         62        640:  77% 120/155 [00:46<00:11,  3.16it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G    0.02004    0.02372          0         94        640:  78% 121/155 [00:46<00:12,  2.81it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G    0.02006    0.02373          0         90        640:  79% 122/155 [00:46<00:10,  3.09it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G    0.02003    0.02374          0         89        640:  79% 123/155 [00:47<00:12,  2.65it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G    0.02004    0.02374          0         80        640:  80% 124/155 [00:47<00:10,  3.00it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G    0.02004    0.02368          0         65        640:  81% 125/155 [00:47<00:10,  2.90it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G    0.02005    0.02364          0         63        640:  81% 126/155 [00:48<00:09,  3.17it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G    0.02008    0.02367          0         93        640:  82% 127/155 [00:48<00:09,  3.09it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G    0.02011    0.02365          0         59        640:  83% 128/155 [00:48<00:08,  3.33it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G    0.02012    0.02362          0         72        640:  83% 129/155 [00:49<00:10,  2.58it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G    0.02012    0.02359          0         71        640:  84% 130/155 [00:49<00:08,  2.88it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G     0.0201    0.02357          0         74        640:  85% 131/155 [00:50<00:11,  2.14it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G    0.02013    0.02358          0         81        640:  85% 132/155 [00:50<00:09,  2.48it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G    0.02014    0.02364          0        104        640:  86% 133/155 [00:51<00:12,  1.79it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G    0.02014    0.02365          0         79        640:  86% 134/155 [00:51<00:10,  2.06it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G    0.02014    0.02362          0         69        640:  87% 135/155 [00:52<00:09,  2.10it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G    0.02014    0.02363          0         98        640:  88% 136/155 [00:52<00:07,  2.39it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G    0.02012    0.02358          0         60        640:  88% 137/155 [00:53<00:08,  2.02it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G    0.02009    0.02356          0         78        640:  89% 138/155 [00:53<00:07,  2.34it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G    0.02012    0.02356          0         83        640:  90% 139/155 [00:54<00:08,  1.98it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G    0.02011    0.02356          0         83        640:  90% 140/155 [00:54<00:06,  2.34it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G     0.0201    0.02358          0         86        640:  91% 141/155 [00:54<00:06,  2.06it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G    0.02011    0.02358          0         79        640:  92% 142/155 [00:55<00:05,  2.40it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G     0.0201     0.0235          0         40        640:  92% 143/155 [00:55<00:05,  2.31it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G     0.0201    0.02356          0        122        640:  93% 144/155 [00:55<00:04,  2.68it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G    0.02008    0.02358          0        104        640:  94% 145/155 [00:56<00:04,  2.42it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G    0.02009    0.02354          0         58        640:  94% 146/155 [00:56<00:03,  2.75it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G     0.0201    0.02355          0         81        640:  95% 147/155 [00:57<00:02,  2.87it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G    0.02008    0.02351          0         70        640:  95% 148/155 [00:57<00:02,  3.13it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G    0.02008    0.02354          0        105        640:  96% 149/155 [00:57<00:02,  2.63it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G    0.02009    0.02356          0         92        640:  97% 150/155 [00:58<00:01,  2.93it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G    0.02011     0.0236          0         96        640:  97% 151/155 [00:58<00:01,  2.80it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G    0.02012    0.02365          0        113        640:  98% 152/155 [00:58<00:00,  3.12it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G    0.02013    0.02365          0         86        640:  99% 153/155 [00:59<00:00,  2.56it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G    0.02016    0.02362          0         57        640:  99% 154/155 [00:59<00:00,  2.87it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.75G    0.02017    0.02363          0         16        640: 100% 155/155 [00:59<00:00,  2.60it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 17/17 [00:06<00:00,  2.53it/s]
#                    all        529       1911      0.801      0.889      0.931      0.677
#
# 50 epochs completed in 0.937 hours.
# Optimizer stripped from runs/train/exp/weights/last.pt, 14.4MB
# Optimizer stripped from runs/train/exp/weights/best.pt, 14.4MB
#
# Validating runs/train/exp/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 17/17 [00:08<00:00,  2.03it/s]
#                    all        529       1911      0.821      0.896      0.945      0.698
# Results saved to runs/train/exp

# %%
# !python val.py --data /content/PCOS/train/data.yaml --weights runs/train/exp/weights/best.pt --img 640 --task test
# Out:
# val: data=/content/PCOS/train/data.yaml, weights=['runs/train/exp/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-413-gf2f86eb3 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# test: Scanning /content/PCOS/train/test/labels... 529 images, 182 backgrounds, 0 corrupt: 100% 529/529 [00:00<00:00, 806.16it/s]
# test: New cache created: /content/PCOS/train/test/labels.cache
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 17/17 [00:08<00:00,  2.04it/s]
#                    all        529       1850      0.795      0.914      0.942      0.699
# Speed: 0.9ms pre-process, 6.7ms inference, 2.0ms NMS per image at shape (32, 3, 640, 640)
# Results saved to runs/val/exp

# %%
from google.colab import files
files.download('/content/yolov5/runs/train/exp/weights/best.pt')

# %% [markdown]
# # testing on the image

# %%
# Clone YOLOv5 and install dependencies
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# !pip install -r requirements.txt
# !pip install gradio

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# !pip install -r requirements.txt

# %%
import sys
sys.path.append('/content/yolov5')

# %%
# Step 1: Install and import dependencies


import gradio as gr
import torch
import numpy as np
from PIL import Image
import cv2
import sys


from models.common import DetectMultiBackend
from utils.general import non_max_suppression, scale_boxes
from utils.plots import Annotator
from utils.augmentations import letterbox

# Load trained model
device = torch.device('cpu')
model = DetectMultiBackend('/content/best2.pt', device=device)

stride = model.stride
names = model.names
model.eval()

# Step 3: Define detection function
def detect_pcos(image: Image.Image):
    try:
        # Convert image to NumPy array and BGR format
        img_np = np.array(image)
        img_bgr = cv2.cvtColor(img_np, cv2.COLOR_RGB2BGR)
        # Resize with padding
        img_resized = letterbox(img_bgr, stride=stride, auto=True)[0]
        img_resized = img_resized.transpose((2, 0, 1))
        img_resized = np.ascontiguousarray(img_resized)
        # Convert to torch tensor
        im_tensor = torch.from_numpy(img_resized).to(model.device).float()
        im_tensor /= 255.0  # Normalize
        if im_tensor.ndimension() == 3:
            im_tensor = im_tensor.unsqueeze(0)  # Add batch dim
        # Inference
        pred = model(im_tensor)
        pred = non_max_suppression(pred, conf_thres=0.25, iou_thres=0.45)
        # Annotate image
        img_display = img_bgr.copy()
        annotator = Annotator(img_display, line_width=2)
        count = 0
        for det in pred:
            if det is not None and len(det):
                count = len(det)
                det[:, :4] = scale_boxes(im_tensor.shape[2:], det[:, :4], img_display.shape).round()
                for *xyxy, conf, cls in det:
                    label = f'{names[int(cls)]} {conf:.2f}'
                    annotator.box_label(xyxy, label, color=(0, 0, 255))

        output_img = annotator.result()
        output_pil = Image.fromarray(cv2.cvtColor(output_img, cv2.COLOR_BGR2RGB))
        result_text = f"✅ PCOS Detected (Follicles: {count})" if count >= 4 else f"❌ No PCOS Detected (Follicles: {count})"
        return output_pil, result_text

    except Exception as e:
        return None, f"❌ Error: {str(e)}"

# Step 4: Create Gradio interface
interface = gr.Interface(
    fn=detect_pcos,
    inputs=gr.Image(type="pil", label="Upload Ultrasound Image"),
    outputs=[gr.Image(type="pil", label="Detected Image"), gr.Textbox(label="Detection Result")],
    title="PCOS Detection from Ultrasound",
    description="Upload an ultrasound image. This tool uses YOLOv5 to detect follicles and determine PCOS."
)

interface.launch(share=True)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://be5707013009c39dcf.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://be5707013009c39dcf.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
! pip install pytesseract
# !sudo apt install tesseract-ocr
# Out:
# Collecting pytesseract
#   Downloading pytesseract-0.3.13-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.11/dist-packages (from pytesseract) (24.2)
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from pytesseract) (11.1.0)
# Downloading pytesseract-0.3.13-py3-none-any.whl (14 kB)
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.13
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 34 not upgraded.

# %%
import pytesseract
from PIL import Image

def detect_pcos(image: Image.Image):
    try:
        # Step 1: Resize image to 640x640
        image = image.resize((640, 640))

        # Step 2: Convert to grayscale for text detection
        gray = cv2.cvtColor(np.array(image), cv2.COLOR_RGB2GRAY)

        # Step 3: Text detection using OCR
        text_detected = pytesseract.image_to_string(gray).strip()
        if len(text_detected) > 5:
            return None, "❌ Text detected in image. Please upload a clean ultrasound scan without text."

        # Step 4: Convert image to NumPy and BGR format for YOLOv5
        img_np = np.array(image)
        img_bgr = cv2.cvtColor(img_np, cv2.COLOR_RGB2BGR)

        # Step 5: Resize with letterbox padding
        img_resized = letterbox(img_bgr, stride=stride, auto=True)[0]
        img_resized = img_resized.transpose((2, 0, 1))
        img_resized = np.ascontiguousarray(img_resized)

        # Step 6: Convert to torch tensor
        im_tensor = torch.from_numpy(img_resized).to(model.device).float()
        im_tensor /= 255.0
        if im_tensor.ndimension() == 3:
            im_tensor = im_tensor.unsqueeze(0)

        # Step 7: Inference
        pred = model(im_tensor)
        pred = non_max_suppression(pred, conf_thres=0.25, iou_thres=0.45)

        # Step 8: Annotate image
        img_display = img_bgr.copy()
        annotator = Annotator(img_display, line_width=2)
        count = 0

        for det in pred:
            if det is not None and len(det):
                count = len(det)
                det[:, :4] = scale_boxes(im_tensor.shape[2:], det[:, :4], img_display.shape).round()
                for *xyxy, conf, cls in det:
                    label = f'{names[int(cls)]} {conf:.2f}'
                    annotator.box_label(xyxy, label, color=(0, 0, 255))

        output_img = annotator.result()
        output_pil = Image.fromarray(cv2.cvtColor(output_img, cv2.COLOR_BGR2RGB))
        result_text = f"✅ PCOS Detected (Follicles: {count})" if count >= 4 else f"❌ No PCOS Detected (Follicles: {count})"

        return output_pil, result_text

    except Exception as e:
        return None, f"❌ Error: {str(e)}"

# %%
# !pip install gradio

# %%
interface = gr.Interface(
    fn=detect_pcos,
    inputs=gr.Image(type="pil", label="Upload Ultrasound Image"),
    outputs=[
        gr.Image(type="pil", label="Detected Image"),
        gr.Textbox(label="Detection Result")
    ],
    title="PCOS Detection from Ultrasound",
    description="Upload an ultrasound image (640x640). This tool detects PCOS based on follicle count using YOLOv5."
)

interface.launch(share=True)  # Use share=False if you want local-only
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://a0b98d5fc612c603ad.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://a0b98d5fc612c603ad.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
